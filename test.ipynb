# %% [markdown]
# # Tokenizer

# %%
from tokenizer import bpe_tokenizer

# %%
with open('texts/pan-tadeusz.txt', 'r') as f:
    text = f.read()
encode, decode, vocab, merges = bpe_tokenizer(text, 10000, 100)
# Out:
# Learnt 0 merges out of 10000
# Learnt 100 merges out of 10000
# Learnt 200 merges out of 10000
# Learnt 300 merges out of 10000
# Learnt 400 merges out of 10000
# Learnt 500 merges out of 10000
# Learnt 600 merges out of 10000
# Learnt 700 merges out of 10000
# Learnt 800 merges out of 10000
# Learnt 900 merges out of 10000
# Learnt 1000 merges out of 10000
# Learnt 1100 merges out of 10000
# Learnt 1200 merges out of 10000
# Learnt 1300 merges out of 10000
# Learnt 1400 merges out of 10000
# Learnt 1500 merges out of 10000
# Learnt 1600 merges out of 10000
# Learnt 1700 merges out of 10000
# Learnt 1800 merges out of 10000
# Learnt 1900 merges out of 10000
# Learnt 2000 merges out of 10000
# Learnt 2100 merges out of 10000
# Learnt 2200 merges out of 10000
# Learnt 2300 merges out of 10000
# Learnt 2400 merges out of 10000
# Learnt 2500 merges out of 10000
# Learnt 2600 merges out of 10000
# Learnt 2700 merges out of 10000
# Learnt 2800 merges out of 10000
# Learnt 2900 merges out of 10000
# Learnt 3000 merges out of 10000
# Learnt 3100 merges out of 10000
# Learnt 3200 merges out of 10000
# Learnt 3300 merges out of 10000
# Learnt 3400 merges out of 10000
# Learnt 3500 merges out of 10000
# Learnt 3600 merges out of 10000
# Learnt 3700 merges out of 10000
# Learnt 3800 merges out of 10000
# Learnt 3900 merges out of 10000
# Learnt 4000 merges out of 10000
# Learnt 4100 merges out of 10000
# Learnt 4200 merges out of 10000
# Learnt 4300 merges out of 10000
# Learnt 4400 merges out of 10000
# Learnt 4500 merges out of 10000
# Learnt 4600 merges out of 10000
# Learnt 4700 merges out of 10000
# Learnt 4800 merges out of 10000
# Learnt 4900 merges out of 10000
# Learnt 5000 merges out of 10000
# Learnt 5100 merges out of 10000
# Learnt 5200 merges out of 10000
# Learnt 5300 merges out of 10000
# Learnt 5400 merges out of 10000
# Learnt 5500 merges out of 10000
# Learnt 5600 merges out of 10000
# Learnt 5700 merges out of 10000
# Learnt 5800 merges out of 10000
# Learnt 5900 merges out of 10000
# Learnt 6000 merges out of 10000
# Learnt 6100 merges out of 10000
# Learnt 6200 merges out of 10000
# Learnt 6300 merges out of 10000
# Learnt 6400 merges out of 10000
# Learnt 6500 merges out of 10000
# Learnt 6600 merges out of 10000
# Learnt 6700 merges out of 10000
# Learnt 6800 merges out of 10000
# Learnt 6900 merges out of 10000
# Learnt 7000 merges out of 10000
# Learnt 7100 merges out of 10000
# Learnt 7200 merges out of 10000
# Learnt 7300 merges out of 10000
# Learnt 7400 merges out of 10000
# Learnt 7500 merges out of 10000
# Learnt 7600 merges out of 10000
# Learnt 7700 merges out of 10000
# Learnt 7800 merges out of 10000
# Learnt 7900 merges out of 10000
# Learnt 8000 merges out of 10000
# Learnt 8100 merges out of 10000
# Learnt 8200 merges out of 10000
# Learnt 8300 merges out of 10000
# Learnt 8400 merges out of 10000
# Learnt 8500 merges out of 10000
# Learnt 8600 merges out of 10000
# Learnt 8700 merges out of 10000
# Learnt 8800 merges out of 10000
# Learnt 8900 merges out of 10000
# Learnt 9000 merges out of 10000
# Learnt 9100 merges out of 10000
# Learnt 9200 merges out of 10000
# Learnt 9300 merges out of 10000
# Learnt 9400 merges out of 10000
# Learnt 9500 merges out of 10000
# Learnt 9600 merges out of 10000
# Learnt 9700 merges out of 10000
# Learnt 9800 merges out of 10000
# Learnt 9900 merges out of 10000

# %% [markdown]
# # Embeddings

# %%
from embeddings import Embedding, SinusoidalPositionalEmbedding

# %%
num_embeddings = 100
block_size = 10
embedding_dim = 6

# %%
embedding = Embedding(num_embeddings, embedding_dim)
positionalEmbedding = SinusoidalPositionalEmbedding(block_size, embedding_dim)

# %%
import random
x = [random.randint(0, num_embeddings) for _ in range(block_size)]

# %%
print(embedding(x))
print(positionalEmbedding(x))
# Out:
# tensor([[-3.4502e-01,  3.0798e-41,  2.8026e-45,  0.0000e+00, -3.4503e-01,
#           3.0798e-41],
#         [ 4.2039e-45,  2.1019e-44, -3.4499e-01,  3.0798e-41,  1.6717e-42,
#           4.5890e-41],
#         [ 1.4013e-45,  3.0798e-41,  9.8091e-45, -1.6094e+29, -3.4503e-01,
#           3.0798e-41],
#         [-3.4498e-01,  3.0798e-41, -3.4500e-01,  3.0798e-41,  7.0065e-45,
#          -1.8448e+29],
#         [-1.5484e+32,  4.5888e-41,  1.4013e-45, -6.6205e+17, -3.4501e-01,
#           3.0798e-41],
#         [ 1.4013e-45,  7.2868e-44,  8.4078e-45,  1.8426e+05, -3.4498e-01,
#           3.0798e-41],
#         [-3.4498e-01,  3.0798e-41,  1.4013e-45,  5.3249e-44,  1.4013e-45,
#           7.1466e-44],
#         [ 1.5681e-42,  3.0798e-41, -3.4502e-01,  3.0798e-41,  9.8091e-45,
#           0.0000e+00],
#         [ 3.6434e-44,  3.0798e-41, -3.2005e+25,  4.5890e-41,  1.4013e-45,
#           3.0798e-41],
#         [-3.4502e-01,  3.0798e-41,  1.5989e-42, -1.4135e+10, -3.4502e-01,
#           3.0798e-41]], grad_fn=<IndexBackward0>)
# tensor([[ 0.0000e+00,  1.0000e+00,  0.0000e+00,  1.0000e+00,  0.0000e+00,
#           1.0000e+00],
#         [ 8.4147e-01,  9.9892e-01,  2.1544e-03,  1.0000e+00,  4.6416e-06,
#           1.0000e+00],
#         [ 9.0930e-01,  9.9569e-01,  4.3089e-03,  1.0000e+00,  9.2832e-06,
#           1.0000e+00],
#         [ 1.4112e-01,  9.9032e-01,  6.4633e-03,  1.0000e+00,  1.3925e-05,
#           1.0000e+00],
#         [-7.5680e-01,  9.8281e-01,  8.6176e-03,  1.0000e+00,  1.8566e-05,
#           1.0000e+00],
#         [-9.5892e-01,  9.7319e-01,  1.0772e-02,  1.0000e+00,  2.3208e-05,
#           1.0000e+00],
#         [-2.7942e-01,  9.6147e-01,  1.2926e-02,  1.0000e+00,  2.7850e-05,
#           1.0000e+00],
#         [ 6.5699e-01,  9.4768e-01,  1.5080e-02,  1.0000e+00,  3.2491e-05,
#           1.0000e+00],
#         [ 9.8936e-01,  9.3185e-01,  1.7235e-02,  1.0000e+00,  3.7133e-05,
#           1.0000e+00],
#         [ 4.1212e-01,  9.1401e-01,  1.9389e-02,  1.0000e+00,  4.1774e-05,
#           1.0000e+00]])

# %% [markdown]
# # load_model

# %%
from save_load_model import load_model
import torch

# %%
model, encode, decode, vocab, merges = load_model("models/mickiewicz_model.pt")

# %%
encode("rasdwa trzy")
# Out:
# [146, 154, 98, 165, 79, 161, 153]

# %%
model(torch.Tensor([[2,5,70]]).long()).shape
# Out:
# /home/antek/projekty_wlasne/A-Simple-GPT-Model/embeddings.py:19: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   x = torch.tensor(x, dtype=torch.long)
# torch.Size([1, 3, 205])

# %%
len(vocab)
# Out:
# 205

# %% [markdown]
# # Training
