# %%
from helpers import  load_bpe_tokenization, load_model, load_encoding

# %%
encode, decode, vocab, merges = load_bpe_tokenization("tokenizers/tokenizer_mickiewicz_010.pt")

# %%
model, config = load_model("models/mickiewicz_gpt_010.pt")

# %%
print(decode(model.generate(encode("Śród takich pól przed laty\nNad brzegiem ruczaju"), max_new_tokens=50)))
# Out:
# Śród takich pól przed laty
# Nad brzegiem ruczaju stary na.
# Czasem hanek,
# Chce —
# (w ark!
#
#     Miede Soplicą
# Nie mógł w zawału — rzekł W który!
# O robawytów bieżyje;
# Źwi wna sługojem wsch

# %%
tr_encoding = load_encoding("encodings/tr_encoding_mickiewicz.pt")

# %%
len(tr_encoding) / 0.9
# Out:
# 254266.66666666666

# %%
len(vocab)
# Out:
# 19718

# %%
vocab[18000:18100]
# Out:
# ['wer',
#  'wes',
#  'wese',
#  'wesel',
#  'wesele',
#  'weseli',
#  'wesoł',
#  'wesoła',
#  'wesoło',
#  'wesołość',
#  'west',
#  'westa',
#  'westarz',
#  'westchnie',
#  'wet',
#  'wez',
#  'weź',
#  'weźmie',
#  'wi',
#  'wi ',
#  'wi i ',
#  'wi z',
#  'wia',
#  'wia ',
#  'wiali się',
#  'wian',
#  'wianek',
#  'wiar',
#  'wiara ',
#  'wiarz',
#  'wiast',
#  'wiasta',
#  'wiasto ',
#  'wiastu',
#  'wiat',
#  'wiatr',
#  'wiatru',
#  'wiaz',
#  'wiazd',
#  'wiazdy ',
#  'wiać',
#  'wiał',
#  'wiaździ',
#  'wica ',
#  'wich',
#  'wici',
#  'wicz',
#  'wicze',
#  'wid',
#  'widać',
#  'wido',
#  'widok',
#  'widz',
#  'widzi',
#  'widzial',
#  'widział',
#  'widziałem',
#  'widziałeś',
#  'widzieć',
#  'widzisz',
#  'widzisz Pański krzyż?\nNie',
#  'widząc',
#  'widzę',
#  'wie',
#  'wie i ',
#  'wie,\nI',
#  'wie, ',
#  'wiec',
#  'wieci',
#  'wiecie',
#  'wiecz',
#  'wiecze',
#  'wiecznie',
#  'wieczności ',
#  'wieczo',
#  'wieczor',
#  'wieczora',
#  'wieczorem',
# ...
